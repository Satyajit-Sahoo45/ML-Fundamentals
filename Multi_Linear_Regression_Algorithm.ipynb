# %%
import pandas as pd

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/home/satyajit-sahoo/Downloads/multiple_linear_regression_dataset.csv")
dataset.head(4)
# Out:
#    age  experience  salary
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130

# %%
dataset.shape
# Out:
# (20, 3)

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset['salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 95.79002513351035

# %%
# y = m1x1 + m2x2 + m3x3 + ----- + c

# %%
lr.coef_
# Out:
# array([-102.88197553, 2191.86022152])

# %%
lr.intercept_
# Out:
# 31439.55229534913

# %%
# y_prd = -102.88197553*age + 2191.86022152*experience + 31439.55229534913

# %%
x.columns
# Out:
# Index(['age', 'experience'], dtype='object')

# %%
lr.predict(x_test)
# Out:
# array([36843.22672444, 48934.22956284, 46639.48736579, 31059.36312867])
