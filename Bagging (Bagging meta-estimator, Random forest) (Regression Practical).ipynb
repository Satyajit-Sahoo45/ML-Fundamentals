# %%
import pandas as pd

# %%
dataset = pd.read_csv("./data/placement.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
x = dataset.iloc[:,:-1]
y = dataset["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
bg = BaggingRegressor(estimator=LinearRegression(), n_estimators=40)
bg.fit(x_train, y_train)
bg.score(x_train, y_train)*100, bg.score(x_test, y_test)*100
# Out:
# (77.58091319982637, 77.38676636953966)

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor(n_estimators=40)
rf.fit(x_train, y_train)
rf.score(x_train, y_train)*100, rf.score(x_test, y_test)*100
# Out:
# (91.73390509315236, 67.61153841574034)
