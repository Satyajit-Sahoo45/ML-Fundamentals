# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"./data/iris(k-means_custering).csv")
dataset.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(2, 21):
    km = KMeans(n_clusters=i, init='k-means++')
    km.fit(dataset)
    wcss.append(km.inertia_)

# %%
# designing diagram between wcss and no. of clusters

# %%
plt.figure(figsize=(10,5))
plt.plot([i for i in range(2, 21)], wcss, marker="o")
plt.xlabel("no of cluster")
plt.xticks([i for i in range(2, 21)])
plt.ylabel("wcss")
plt.grid(axis="x")
plt.show()

# %%
# check the perfect prediction with 3 cluster

# %%
kmn = KMeans(n_clusters=3)
dataset["predict"] = kmn.fit_predict(dataset)

# %%
sns.pairplot(data=dataset, hue="predict")
plt.show()

# %%
org_data = pd.read_csv(r"./data/IRIS.csv")

# %%
sns.pairplot(data=org_data, hue="species")
plt.show()
