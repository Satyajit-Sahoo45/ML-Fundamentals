# %%
import pandas as pd

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/home/satyajit-sahoo/Downloads/placement.csv")
dataset.head(4)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67

# %%
sns.scatterplot(x="cgpa", y="package", data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]] # input data
y = dataset["package"] #Output data

# %%
# Import the library for preparing data splitting
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Import the library for the lineat regression
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# y = m * x + c

# %%
lr.coef_
# Out:
# array([0.57425647])

# %%
lr.intercept_
# Out:
# -1.02700693745421

# %%
# y = 0.57425647*x -1.02700693745421

# %%
# to find accuracy

lr.score(x_test, y_test)*100
# Out:
# 77.30984312051673

# %%
lr.predict([[6.89]])
# Out:
# /home/satyajit-sahoo/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.92962016])

# %%
0.57425647*6.89 -1.02700693745421
# Out:
# 2.92962014084579

# %%
y_Prd = lr.predict(x)

# %%
sns.scatterplot(x="cgpa", y="package", data=dataset)
plt.plot(dataset["cgpa"], y_Prd, c="red")
plt.legend(["original data", "predict line"])
plt.show()
