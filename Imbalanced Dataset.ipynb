# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"./data/Social_Network_Ads.csv")
dataset.head(4)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=2, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 81.25

# %%
lr.predict([[45, 26000]])
# Out:
# /home/satyajit-sahoo/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# the result seems to be biased because for 45, 26000 the result should be '1', not '0'...as the not of training data has '0' 
# In the majority, the model is trained according to the majority data. To tackle this biasedness issue, we need to balance the dataset.

# Technique to handle this issue
#  1 - Random Over-Sampling
#  2 - Random Under-Sampling
